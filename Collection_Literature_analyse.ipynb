# %% [markdown]
# # Literary text editions in the collection of the Antwerp University Library
#
# ## Aim of the collection analysis
#
# The aim of this document is to show how SQlite and Python can help with a collection analysis. We will focus on the literary text editions which are relevant for students and researchers of the Faculty of Arts, especially of the Literary Department. These items are after all the primary sources for their work.
#
# The collection of literary text editions has been mainly built up by the Department of Literature and to a lesser extent by the Department of Linguistics. There were obviously also donations and other departments also bought, albeit to a very limited extent, some literary publications.
#
# The catalog records of text editions contains a keyword to distinguish them from other publications. We will limit our queries to the following keywords: 'Tekstuitgave' (text editions), 'Theatertekst' (theater text), 'Poëzie' (poetry), 'Verhalend proza' (narrative prose), and 'Bloemlezing' (anthology).
#
# Note: The cataloguing rules related to the keywords for text editions were changed in 2008. Until that year there was no distinction between theater text, poetry, etc. All text editions got the same general keyword: 'Text editions'. This means that a work of poetry before the change got the keyword 'text edition' and not the keyword 'poetry'. In short, it is not possible for example to focus the searches only to poetry, because in that case you will miss a lot of works of poetry in your result set.
#
# ## Dataset
#
# This collection analysis uses bibliographic descriptions (catalog records) from the Antwerp University Library catalog, managed by the library system Brocade (dataset on 5/9/2022), and not the number of items (physical copies of a book). In other words, each description has one or more items attached to it. Keep in mind that a work (e.g. Het verdriet van België of Hugo Claus) may have several bibliographic descriptions.
#
# The dataset is exported as a SQLite database and queried with the help of Python libraries (sqlite3, numpy, and pandas).

# %% [markdown]
# ## 1 : Authors and translators
#
# - Topic 1: Which authors of text editions appear most frequently in the library collection (reading rooms and stack rooms)?
# - Topic 2: The same question for the translators.
# - Topic 3: Focus on the translations of Hugo Claus work: languages and titles (sample).
# - Topic 4: The translations of Williams Shakespeare work: focus on the Dutch translations.
#
#
# Note: The cataloguing rules for authors changed in June 2013. The cataloguers now must record all authors/editors mentioned on the title page, whereas in the past they had to limit themselves to the first three authors/editors. However, this is not of a significant relevance because text editions with more than three authors are quite rare.

# %%
# Query for Topic 1

import sqlite3
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

PATH_TO_DB = '/Users/lmaggior/OneDrive - Universiteit Antwerpen/programmeren/sqlite/UA_cst.sqlite'

# PATH_TO_DB = '/Users/LCD150030/OneDrive - Universiteit Antwerpen/programmeren/sqlite/UA_cst.sqlite'

conn = sqlite3.connect(PATH_TO_DB)
cursor = conn.cursor()

'''
Function to generate pandas DataFrame's from the result set of the sqlite query
'''
def execute_cursor(query, columns_input):
    cursor.execute(query)
    data = {row for row in cursor.fetchall()}
    data_frame = pd.DataFrame(data, columns = columns_input)
    return data_frame

'''
Function to counts records and to stylize the result table
'''
def styling_frame_count (data_frame, column, head):
    counts = data_frame[column].value_counts()
    counts_head = counts.head(head)
    styling = counts_head.to_frame('Number of records').style.set_table_styles([dict(selector='th', props=[('text-align', 'left')])])
    alignment = styling.set_properties(**{'text-align': 'left'})
    display (alignment)
    
'''
Function to stylize the result table when no records have to be counted
'''  
    
def styling_frame (data_frame, head):
    if head == 0:
        styling = data_frame.style.set_table_styles([dict(selector='th', props=[('text-align', 'left')])])
        alignment = styling.set_properties(**{'text-align': 'left'})
        display (alignment)
    else:
        data_frame_head = data_frame.head(head)
        styling = data_frame_head.style.set_table_styles([dict(selector='th', props=[('text-align', 'left')])])
        alignment = styling.set_properties(**{'text-align': 'left'})
        display (alignment)
        
        
'''
Function to print the heading of the result table
'''        

def print_heading (text):
    print("\n \n \033[1m" + f'{text} \n \033[0m ')
    
    
query1 = '''

SELECT 
    token.cloi,
    title_ti as Title,
    author_fn || ', ' || author_vn AS Author 
FROM token 
JOIN 
    author ON token.cloi = author.cloi
JOIN 
    holding ON author.cloi = holding.cloi
JOIN 
    title ON holding.cloi = title.cloi
JOIN 
    subject ON subject.cloi = title.cloi
WHERE 
subject_ty LIKE 'PT' 
AND author_fu LIKE 'aut'
AND author_fn NOT LIKE 'e.a.'
AND holding.lib LIKE 'UA-CST'
AND title_ty LIKE 'h'
AND subject_vw LIKE 'Tekstuitgave'

UNION

SELECT 
    token.cloi,
    title_ti as Title,
    author_fn || ', ' || author_vn AS Author 
FROM token 
JOIN 
    author ON token.cloi = author.cloi
JOIN 
    holding ON author.cloi = holding.cloi
JOIN 
    title ON holding.cloi = title.cloi
JOIN 
    subject ON subject.cloi = title.cloi
WHERE 
subject_ty LIKE 'PT' 
AND author_fu LIKE 'aut'
AND author_fn NOT LIKE 'e.a.'
AND holding.lib like 'UA-CST'
AND title_ty LIKE 'h'
AND subject_vw LIKE 'Theatertekst'

UNION

SELECT 
    token.cloi,
    title_ti as Title,
    author_fn || ', ' || author_vn AS Author 
FROM token 
JOIN 
    author ON token.cloi = author.cloi
JOIN 
    holding ON author.cloi = holding.cloi
JOIN 
    title ON holding.cloi = title.cloi
JOIN 
    subject ON subject.cloi = title.cloi
WHERE 
subject_ty LIKE 'PT' 
AND author_fu LIKE 'aut'
AND author_fn NOT LIKE 'e.a.'
AND holding.lib LIKE 'UA-CST'
AND title_ty LIKE 'h'
AND subject_vw LIKE 'Poëzie'

UNION

SELECT 
    token.cloi,
    title_ti as Title,
    author_fn || ', ' || author_vn AS Author 
FROM token 
JOIN 
    author ON token.cloi = author.cloi
JOIN 
    holding ON author.cloi = holding.cloi
JOIN 
    title ON holding.cloi = title.cloi
JOIN 
    subject ON subject.cloi = title.cloi
WHERE 
subject_ty LIKE 'PT' 
AND author_fu LIKE 'aut'
AND author_fn NOT LIKE 'e.a.'
AND holding.lib LIKE 'UA-CST'
AND title_ty LIKE 'h'
AND subject_vw LIKE 'Verhalend proza'

UNION

SELECT 
    token.cloi,
    title_ti as Title,
    author_fn || ', ' || author_vn AS Author 
FROM token 
JOIN 
    author  ON token.cloi = author.cloi
JOIN 
    holding ON author.cloi = holding.cloi
JOIN 
    title ON holding.cloi = title.cloi
JOIN 
    subject ON subject.cloi = title.cloi
WHERE 
subject_ty LIKE 'PT' 
AND author_fu LIKE 'aut'
AND author_fn NOT LIKE 'e.a.'
AND holding.lib LIKE 'UA-CST'
AND title_ty LIKE 'h'
AND subject_vw LIKE 'Bloemlezing'

'''
print_heading('Authors of text editions in the Library collection (top 20)')
styling_frame_count(execute_cursor(query1, ['cloi', 'Title', 'Author']), 'Author', 20)

# Query for Topic 2

query2 = '''
SELECT 
    token.cloi,
    title_ti as Title,
    author_fn || ', ' || author_vn as Author 
FROM token 
JOIN 
    author  on token.cloi = author.cloi
JOIN 
    holding on author.cloi = holding.cloi
JOIN 
    title on holding.cloi = title.cloi
JOIN 
    subject on subject.cloi = title.cloi 
WHERE 
subject_ty like 'PT' 
AND author_fu like 'trl'
AND author_fn not like 'e.a.'
AND holding.lib like 'UA-CST'
AND title_ty like 'h'
AND subject_vw like 'Tekstuitgave'

UNION

SELECT 
    token.cloi,
    title_ti as Title,
    author_fn || ', ' || author_vn as Author 
FROM token 
JOIN 
    author  on token.cloi = author.cloi
JOIN 
    holding on author.cloi = holding.cloi
JOIN 
    title on holding.cloi = title.cloi
JOIN 
    subject on subject.cloi = title.cloi
WHERE 
subject_ty like 'PT' 
AND author_fu like 'trl'
AND author_fn not like 'e.a.'
AND holding.lib like 'UA-CST'
AND title_ty like 'h'
AND subject_vw like 'Theatertekst'

UNION

SELECT 
    token.cloi,
    title_ti as Title,
    author_fn || ', ' || author_vn as Author 
FROM token 
JOIN 
    author  on token.cloi = author.cloi
JOIN 
    holding on author.cloi = holding.cloi
JOIN 
    title on holding.cloi = title.cloi
JOIN 
    subject on subject.cloi = title.cloi
WHERE 
subject_ty like 'PT' 
AND author_fu like 'trl'
AND author_fn not like 'e.a.'
AND holding.lib like 'UA-CST'
AND title_ty like 'h'
AND subject_vw like 'Poëzie'

UNION

SELECT 
    token.cloi,
    title_ti as Title,
    author_fn || ', ' || author_vn as Author 
FROM token 
JOIN 
    author  on token.cloi = author.cloi
JOIN 
    holding on author.cloi = holding.cloi
JOIN 
    title on holding.cloi = title.cloi
JOIN 
    subject on subject.cloi = title.cloi
WHERE 
subject_ty like 'PT' 
AND author_fu like 'trl'
AND author_fn not like 'e.a.'
AND holding.lib like 'UA-CST'
AND title_ty like 'h'
AND subject_vw like 'Verhalend proza'

UNION

SELECT 
    token.cloi,
    title_ti as Title,
    author_fn || ', ' || author_vn as Author 
FROM token 
JOIN 
    author  on token.cloi = author.cloi
JOIN 
    holding on author.cloi = holding.cloi
JOIN 
    title on holding.cloi = title.cloi
JOIN 
    subject on subject.cloi = title.cloi
WHERE 
subject_ty like 'PT' 
AND author_fu like 'trl'
AND author_fn not like 'e.a.'
AND holding.lib like 'UA-CST'
AND title_ty like 'h'
AND subject_vw like 'Beeldverhaal'

UNION

SELECT 
    token.cloi,
    title_ti as Title,
    author_fn || ', ' || author_vn as Author 
FROM token 
JOIN 
    author  on token.cloi = author.cloi
JOIN 
    holding on author.cloi = holding.cloi
JOIN 
    title on holding.cloi = title.cloi
JOIN 
    subject on subject.cloi = title.cloi
WHERE 
subject_ty like 'PT' 
AND author_fu like 'trl'
AND author_fn not like 'e.a.'
AND holding.lib like 'UA-CST'
AND title_ty like 'h'
AND subject_vw like 'Bloemlezing'
'''
print_heading('Translators of text editions in the Library collection (top 20)')
styling_frame_count(execute_cursor(query2, ['cloi', 'Title', 'Author']), 'Author', 20)

# Query for Topic 3

query3 = '''
SELECT 
token.cloi,
title_ti as Title,
author.author_fn || ', ' || author.author_vn as Author,
author2.author_fn || ', ' || author2.author_vn as Translator,
language_lg as Language
FROM token 
JOIN 
author ON token.cloi = author.cloi
JOIN 
holding ON author.cloi = holding.cloi
JOIN 
title ON holding.cloi = title.cloi
JOIN 
subject ON subject.cloi = title.cloi
JOIN 
language ON subject.cloi = language.cloi
JOIN 
holding2 on holding2.cloi = language.cloi
JOIN 
author2 on holding2.cloi = author2.cloi
WHERE 
subject_ty LIKE 'PT'
AND author.author_fu LIKE 'aut'
AND Author LIKE 'Claus, Hugo'
AND author2.author_fu LIKE 'trl'
AND ((holding.lib LIKE 'UA-CST' AND holding.holding_pk LIKE 'T&L%') OR (holding2.lib LIKE 'UA-CST' AND holding2.holding_pk LIKE 'MAG%'))
AND title_ty LIKE 'h'
AND Language  NOT LIKE 'dut'
GROUP BY token.cloi
'''
print_heading('Claus works: languages of the translations')
styling_frame_count(execute_cursor(query3,  ['cloi', 'Title', 'Author', 'Translator', 'Language']), 'Language', 20)
print_heading('Claus works: titles and translators (sample of 20 titles)')
styling_frame(execute_cursor(query3, ['cloi', 'Title', 'Author', 'Translator', 'Language']), 20)

# Query for Topic 4

query4 = '''
SELECT 
title_ti as Title,
author.author_fn || ', ' || author.author_vn as Author,
author2.author_fn || ', ' || author2.author_vn as Translator 
FROM token 
JOIN 
author ON token.cloi = author.cloi
JOIN 
holding ON author.cloi = holding.cloi
JOIN 
title ON holding.cloi = title.cloi
JOIN 
subject ON subject.cloi = title.cloi
JOIN 
language ON subject.cloi = language.cloi
JOIN 
holding2 on holding2.cloi = language.cloi
JOIN 
author2 on holding2.cloi = author2.cloi
WHERE 
subject_ty LIKE 'PT'
AND author.author_fu LIKE 'aut'
AND Author LIKE 'Shakespeare, William'
AND author2.author_fu LIKE 'trl'
AND ((holding.lib LIKE 'UA-CST' AND holding.holding_pk LIKE 'T&L%') OR (holding2.lib LIKE 'UA-CST' AND holding2.holding_pk LIKE 'MAG%'))
AND title_ty LIKE 'h'
AND language_lg LIKE 'dut'
GROUP BY token.cloi
'''
print_heading(' Translations of Shakespeare works in Dutch')
styling_frame(execute_cursor(query4, ['Title', 'Author', 'Translator']), 0)
# Out:
#
#  Authors of text editions in the Library collection (top 20)
# <style  type="text/css" >
#     #T_209f5d38_cf93_11ec_a42e_3448ed2f2355 th {
#           text-align: left;
#     }    #T_209f5d38_cf93_11ec_a42e_3448ed2f2355row0_col0 {
#             text-align:  left;
#         }    #T_209f5d38_cf93_11ec_a42e_3448ed2f2355row1_col0 {
#             text-align:  left;
#         }    #T_209f5d38_cf93_11ec_a42e_3448ed2f2355row2_col0 {
#             text-align:  left;
#         }    #T_209f5d38_cf93_11ec_a42e_3448ed2f2355row3_col0 {
#             text-align:  left;
#         }    #T_209f5d38_cf93_11ec_a42e_3448ed2f2355row4_col0 {
#             text-align:  left;
#         }    #T_209f5d38_cf93_11ec_a42e_3448ed2f2355row5_col0 {
#             text-align:  left;
#         }    #T_209f5d38_cf93_11ec_a42e_3448ed2f2355row6_col0 {
#             text-align:  left;
#         }    #T_209f5d38_cf93_11ec_a42e_3448ed2f2355row7_col0 {
#             text-align:  left;
#         }    #T_209f5d38_cf93_11ec_a42e_3448ed2f2355row8_col0 {
#             text-align:  left;
#         }    #T_209f5d38_cf93_11ec_a42e_3448ed2f2355row9_col0 {
#             text-align:  left;
#         }    #T_209f5d38_cf93_11ec_a42e_3448ed2f2355row10_col0 {
#             text-align:  left;
#         }    #T_209f5d38_cf93_11ec_a42e_3448ed2f2355row11_col0 {
#             text-align:  left;
#         }    #T_209f5d38_cf93_11ec_a42e_3448ed2f2355row12_col0 {
#             text-align:  left;
#         }    #T_209f5d38_cf93_11ec_a42e_3448ed2f2355row13_col0 {
#             text-align:  left;
#         }    #T_209f5d38_cf93_11ec_a42e_3448ed2f2355row14_col0 {
#             text-align:  left;
#         }    #T_209f5d38_cf93_11ec_a42e_3448ed2f2355row15_col0 {
#             text-align:  left;
#         }    #T_209f5d38_cf93_11ec_a42e_3448ed2f2355row16_col0 {
#             text-align:  left;
#         }    #T_209f5d38_cf93_11ec_a42e_3448ed2f2355row17_col0 {
#             text-align:  left;
#         }    #T_209f5d38_cf93_11ec_a42e_3448ed2f2355row18_col0 {
#             text-align:  left;
#         }    #T_209f5d38_cf93_11ec_a42e_3448ed2f2355row19_col0 {
#             text-align:  left;
#         }</style><table id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of records</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355level0_row0" class="row_heading level0 row0" >Claus, Hugo</th>
#                         <td id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355row0_col0" class="data row0 col0" >657</td>
#             </tr>
#             <tr>
#                         <th id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355level0_row1" class="row_heading level0 row1" >Grimm, </th>
#                         <td id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355row1_col0" class="data row1 col0" >532</td>
#             </tr>
#             <tr>
#                         <th id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355level0_row2" class="row_heading level0 row2" >Shakespeare, William</th>
#                         <td id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355row2_col0" class="data row2 col0" >485</td>
#             </tr>
#             <tr>
#                         <th id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355level0_row3" class="row_heading level0 row3" >Cicero, Marcus Tullius</th>
#                         <td id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355row3_col0" class="data row3 col0" >432</td>
#             </tr>
#             <tr>
#                         <th id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355level0_row4" class="row_heading level0 row4" >Fontaine, de La, Jean</th>
#                         <td id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355row4_col0" class="data row4 col0" >414</td>
#             </tr>
#             <tr>
#                         <th id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355level0_row5" class="row_heading level0 row5" >Vondel, van den, Joost</th>
#                         <td id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355row5_col0" class="data row5 col0" >355</td>
#             </tr>
#             <tr>
#                         <th id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355level0_row6" class="row_heading level0 row6" >Gezelle, Guido</th>
#                         <td id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355row6_col0" class="data row6 col0" >324</td>
#             </tr>
#             <tr>
#                         <th id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355level0_row7" class="row_heading level0 row7" >Boon, Louis Paul</th>
#                         <td id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355row7_col0" class="data row7 col0" >305</td>
#             </tr>
#             <tr>
#                         <th id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355level0_row8" class="row_heading level0 row8" >Walschap, Gerard</th>
#                         <td id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355row8_col0" class="data row8 col0" >289</td>
#             </tr>
#             <tr>
#                         <th id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355level0_row9" class="row_heading level0 row9" >Conscience, Hendrik</th>
#                         <td id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355row9_col0" class="data row9 col0" >272</td>
#             </tr>
#             <tr>
#                         <th id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355level0_row10" class="row_heading level0 row10" >Simenon, Georges</th>
#                         <td id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355row10_col0" class="data row10 col0" >241</td>
#             </tr>
#             <tr>
#                         <th id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355level0_row11" class="row_heading level0 row11" >Goethe, von, Johann Wolfgang</th>
#                         <td id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355row11_col0" class="data row11 col0" >224</td>
#             </tr>
#             <tr>
#                         <th id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355level0_row12" class="row_heading level0 row12" >Aristoteles, </th>
#                         <td id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355row12_col0" class="data row12 col0" >200</td>
#             </tr>
#             <tr>
#                         <th id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355level0_row13" class="row_heading level0 row13" >Plato, </th>
#                         <td id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355row13_col0" class="data row13 col0" >194</td>
#             </tr>
#             <tr>
#                         <th id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355level0_row14" class="row_heading level0 row14" >Balzac, de, Honoré</th>
#                         <td id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355row14_col0" class="data row14 col0" >183</td>
#             </tr>
#             <tr>
#                         <th id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355level0_row15" class="row_heading level0 row15" >Aesopus, </th>
#                         <td id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355row15_col0" class="data row15 col0" >177</td>
#             </tr>
#             <tr>
#                         <th id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355level0_row16" class="row_heading level0 row16" >Joyce, James</th>
#                         <td id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355row16_col0" class="data row16 col0" >168</td>
#             </tr>
#             <tr>
#                         <th id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355level0_row17" class="row_heading level0 row17" >Horatius Flaccus, Quintus</th>
#                         <td id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355row17_col0" class="data row17 col0" >168</td>
#             </tr>
#             <tr>
#                         <th id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355level0_row18" class="row_heading level0 row18" >Vestdijk, Simon</th>
#                         <td id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355row18_col0" class="data row18 col0" >164</td>
#             </tr>
#             <tr>
#                         <th id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355level0_row19" class="row_heading level0 row19" >Couperus, Louis</th>
#                         <td id="T_209f5d38_cf93_11ec_a42e_3448ed2f2355row19_col0" class="data row19 col0" >149</td>
#
#  Translators of text editions in the Library collection (top 20)
# <style  type="text/css" >
#     #T_22994a52_cf93_11ec_b4f0_3448ed2f2355 th {
#           text-align: left;
#     }    #T_22994a52_cf93_11ec_b4f0_3448ed2f2355row0_col0 {
#             text-align:  left;
#         }    #T_22994a52_cf93_11ec_b4f0_3448ed2f2355row1_col0 {
#             text-align:  left;
#         }    #T_22994a52_cf93_11ec_b4f0_3448ed2f2355row2_col0 {
#             text-align:  left;
#         }    #T_22994a52_cf93_11ec_b4f0_3448ed2f2355row3_col0 {
#             text-align:  left;
#         }    #T_22994a52_cf93_11ec_b4f0_3448ed2f2355row4_col0 {
#             text-align:  left;
#         }    #T_22994a52_cf93_11ec_b4f0_3448ed2f2355row5_col0 {
#             text-align:  left;
#         }    #T_22994a52_cf93_11ec_b4f0_3448ed2f2355row6_col0 {
#             text-align:  left;
#         }    #T_22994a52_cf93_11ec_b4f0_3448ed2f2355row7_col0 {
#             text-align:  left;
#         }    #T_22994a52_cf93_11ec_b4f0_3448ed2f2355row8_col0 {
#             text-align:  left;
#         }    #T_22994a52_cf93_11ec_b4f0_3448ed2f2355row9_col0 {
#             text-align:  left;
#         }    #T_22994a52_cf93_11ec_b4f0_3448ed2f2355row10_col0 {
#             text-align:  left;
#         }    #T_22994a52_cf93_11ec_b4f0_3448ed2f2355row11_col0 {
#             text-align:  left;
#         }    #T_22994a52_cf93_11ec_b4f0_3448ed2f2355row12_col0 {
#             text-align:  left;
#         }    #T_22994a52_cf93_11ec_b4f0_3448ed2f2355row13_col0 {
#             text-align:  left;
#         }    #T_22994a52_cf93_11ec_b4f0_3448ed2f2355row14_col0 {
#             text-align:  left;
#         }    #T_22994a52_cf93_11ec_b4f0_3448ed2f2355row15_col0 {
#             text-align:  left;
#         }    #T_22994a52_cf93_11ec_b4f0_3448ed2f2355row16_col0 {
#             text-align:  left;
#         }    #T_22994a52_cf93_11ec_b4f0_3448ed2f2355row17_col0 {
#             text-align:  left;
#         }    #T_22994a52_cf93_11ec_b4f0_3448ed2f2355row18_col0 {
#             text-align:  left;
#         }    #T_22994a52_cf93_11ec_b4f0_3448ed2f2355row19_col0 {
#             text-align:  left;
#         }</style><table id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of records</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355level0_row0" class="row_heading level0 row0" >Guerne, Armel</th>
#                         <td id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355row0_col0" class="data row0 col0" >33</td>
#             </tr>
#             <tr>
#                         <th id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355level0_row1" class="row_heading level0 row1" >Burgersdijk, Leendert A.J.</th>
#                         <td id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355row1_col0" class="data row1 col0" >31</td>
#             </tr>
#             <tr>
#                         <th id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355level0_row2" class="row_heading level0 row2" >Courteaux, Willy</th>
#                         <td id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355row2_col0" class="data row2 col0" >30</td>
#             </tr>
#             <tr>
#                         <th id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355level0_row3" class="row_heading level0 row3" >Vondel, van den, Joost</th>
#                         <td id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355row3_col0" class="data row3 col0" >30</td>
#             </tr>
#             <tr>
#                         <th id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355level0_row4" class="row_heading level0 row4" >Claus, Hugo</th>
#                         <td id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355row4_col0" class="data row4 col0" >28</td>
#             </tr>
#             <tr>
#                         <th id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355level0_row5" class="row_heading level0 row5" >Durand, Pierre</th>
#                         <td id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355row5_col0" class="data row5 col0" >24</td>
#             </tr>
#             <tr>
#                         <th id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355level0_row6" class="row_heading level0 row6" >Chouraqui, André</th>
#                         <td id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355row6_col0" class="data row6 col0" >23</td>
#             </tr>
#             <tr>
#                         <th id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355level0_row7" class="row_heading level0 row7" >Castier, Jules</th>
#                         <td id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355row7_col0" class="data row7 col0" >22</td>
#             </tr>
#             <tr>
#                         <th id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355level0_row8" class="row_heading level0 row8" >Pressler, Mirjam</th>
#                         <td id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355row8_col0" class="data row8 col0" >22</td>
#             </tr>
#             <tr>
#                         <th id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355level0_row9" class="row_heading level0 row9" >Boutens, Pieter Cornelis</th>
#                         <td id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355row9_col0" class="data row9 col0" >22</td>
#             </tr>
#             <tr>
#                         <th id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355level0_row10" class="row_heading level0 row10" >Hermanowski, Georg</th>
#                         <td id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355row10_col0" class="data row10 col0" >21</td>
#             </tr>
#             <tr>
#                         <th id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355level0_row11" class="row_heading level0 row11" >Altena, van, Ernst</th>
#                         <td id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355row11_col0" class="data row11 col0" >20</td>
#             </tr>
#             <tr>
#                         <th id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355level0_row12" class="row_heading level0 row12" >Ceelen, Adriaan</th>
#                         <td id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355row12_col0" class="data row12 col0" >20</td>
#             </tr>
#             <tr>
#                         <th id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355level0_row13" class="row_heading level0 row13" >Suchtelen, van, Nico</th>
#                         <td id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355row13_col0" class="data row13 col0" >19</td>
#             </tr>
#             <tr>
#                         <th id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355level0_row14" class="row_heading level0 row14" >Poppe, Andries</th>
#                         <td id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355row14_col0" class="data row14 col0" >19</td>
#             </tr>
#             <tr>
#                         <th id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355level0_row15" class="row_heading level0 row15" >Sabarte Belacortu, Mariolein</th>
#                         <td id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355row15_col0" class="data row15 col0" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355level0_row16" class="row_heading level0 row16" >Bremt, van den, Stefaan</th>
#                         <td id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355row16_col0" class="data row16 col0" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355level0_row17" class="row_heading level0 row17" >Komrij, Gerrit</th>
#                         <td id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355row17_col0" class="data row17 col0" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355level0_row18" class="row_heading level0 row18" >Nijmeijer, Peter</th>
#                         <td id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355row18_col0" class="data row18 col0" >17</td>
#             </tr>
#             <tr>
#                         <th id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355level0_row19" class="row_heading level0 row19" >Achlama, Ruth</th>
#                         <td id="T_22994a52_cf93_11ec_b4f0_3448ed2f2355row19_col0" class="data row19 col0" >17</td>
#
#  Claus works: languages of the translations
# <style  type="text/css" >
#     #T_26ded3ba_cf93_11ec_80db_3448ed2f2355 th {
#           text-align: left;
#     }    #T_26ded3ba_cf93_11ec_80db_3448ed2f2355row0_col0 {
#             text-align:  left;
#         }    #T_26ded3ba_cf93_11ec_80db_3448ed2f2355row1_col0 {
#             text-align:  left;
#         }    #T_26ded3ba_cf93_11ec_80db_3448ed2f2355row2_col0 {
#             text-align:  left;
#         }    #T_26ded3ba_cf93_11ec_80db_3448ed2f2355row3_col0 {
#             text-align:  left;
#         }    #T_26ded3ba_cf93_11ec_80db_3448ed2f2355row4_col0 {
#             text-align:  left;
#         }    #T_26ded3ba_cf93_11ec_80db_3448ed2f2355row5_col0 {
#             text-align:  left;
#         }    #T_26ded3ba_cf93_11ec_80db_3448ed2f2355row6_col0 {
#             text-align:  left;
#         }    #T_26ded3ba_cf93_11ec_80db_3448ed2f2355row7_col0 {
#             text-align:  left;
#         }    #T_26ded3ba_cf93_11ec_80db_3448ed2f2355row8_col0 {
#             text-align:  left;
#         }    #T_26ded3ba_cf93_11ec_80db_3448ed2f2355row9_col0 {
#             text-align:  left;
#         }    #T_26ded3ba_cf93_11ec_80db_3448ed2f2355row10_col0 {
#             text-align:  left;
#         }    #T_26ded3ba_cf93_11ec_80db_3448ed2f2355row11_col0 {
#             text-align:  left;
#         }    #T_26ded3ba_cf93_11ec_80db_3448ed2f2355row12_col0 {
#             text-align:  left;
#         }    #T_26ded3ba_cf93_11ec_80db_3448ed2f2355row13_col0 {
#             text-align:  left;
#         }    #T_26ded3ba_cf93_11ec_80db_3448ed2f2355row14_col0 {
#             text-align:  left;
#         }    #T_26ded3ba_cf93_11ec_80db_3448ed2f2355row15_col0 {
#             text-align:  left;
#         }    #T_26ded3ba_cf93_11ec_80db_3448ed2f2355row16_col0 {
#             text-align:  left;
#         }    #T_26ded3ba_cf93_11ec_80db_3448ed2f2355row17_col0 {
#             text-align:  left;
#         }    #T_26ded3ba_cf93_11ec_80db_3448ed2f2355row18_col0 {
#             text-align:  left;
#         }    #T_26ded3ba_cf93_11ec_80db_3448ed2f2355row19_col0 {
#             text-align:  left;
#         }</style><table id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of records</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355level0_row0" class="row_heading level0 row0" >fre</th>
#                         <td id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355row0_col0" class="data row0 col0" >36</td>
#             </tr>
#             <tr>
#                         <th id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355level0_row1" class="row_heading level0 row1" >ger</th>
#                         <td id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355row1_col0" class="data row1 col0" >28</td>
#             </tr>
#             <tr>
#                         <th id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355level0_row2" class="row_heading level0 row2" >eng</th>
#                         <td id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355row2_col0" class="data row2 col0" >17</td>
#             </tr>
#             <tr>
#                         <th id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355level0_row3" class="row_heading level0 row3" >swe</th>
#                         <td id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355row3_col0" class="data row3 col0" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355level0_row4" class="row_heading level0 row4" >nor</th>
#                         <td id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355row4_col0" class="data row4 col0" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355level0_row5" class="row_heading level0 row5" >spa</th>
#                         <td id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355row5_col0" class="data row5 col0" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355level0_row6" class="row_heading level0 row6" >afr</th>
#                         <td id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355row6_col0" class="data row6 col0" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355level0_row7" class="row_heading level0 row7" >pol</th>
#                         <td id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355row7_col0" class="data row7 col0" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355level0_row8" class="row_heading level0 row8" >cze</th>
#                         <td id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355row8_col0" class="data row8 col0" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355level0_row9" class="row_heading level0 row9" >ita</th>
#                         <td id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355row9_col0" class="data row9 col0" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355level0_row10" class="row_heading level0 row10" >dan</th>
#                         <td id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355row10_col0" class="data row10 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355level0_row11" class="row_heading level0 row11" >gre</th>
#                         <td id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355row11_col0" class="data row11 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355level0_row12" class="row_heading level0 row12" >cat</th>
#                         <td id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355row12_col0" class="data row12 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355level0_row13" class="row_heading level0 row13" >bul</th>
#                         <td id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355row13_col0" class="data row13 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355level0_row14" class="row_heading level0 row14" >por</th>
#                         <td id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355row14_col0" class="data row14 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355level0_row15" class="row_heading level0 row15" >rum</th>
#                         <td id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355row15_col0" class="data row15 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355level0_row16" class="row_heading level0 row16" >lat</th>
#                         <td id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355row16_col0" class="data row16 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355level0_row17" class="row_heading level0 row17" >slo</th>
#                         <td id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355row17_col0" class="data row17 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355level0_row18" class="row_heading level0 row18" >slv</th>
#                         <td id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355row18_col0" class="data row18 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355level0_row19" class="row_heading level0 row19" >rus</th>
#                         <td id="T_26ded3ba_cf93_11ec_80db_3448ed2f2355row19_col0" class="data row19 col0" >1</td>
#             </tr>
#     </tbody></table>
#
#  Claus works: titles and translators (sample of 20 titles)
# <style  type="text/css" >
#     #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355 th {
#           text-align: left;
#     }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row0_col0 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row0_col1 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row0_col2 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row0_col3 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row0_col4 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row1_col0 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row1_col1 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row1_col2 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row1_col3 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row1_col4 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row2_col0 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row2_col1 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row2_col2 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row2_col3 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row2_col4 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row3_col0 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row3_col1 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row3_col2 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row3_col3 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row3_col4 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row4_col0 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row4_col1 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row4_col2 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row4_col3 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row4_col4 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row5_col0 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row5_col1 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row5_col2 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row5_col3 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row5_col4 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row6_col0 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row6_col1 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row6_col2 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row6_col3 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row6_col4 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row7_col0 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row7_col1 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row7_col2 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row7_col3 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row7_col4 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row8_col0 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row8_col1 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row8_col2 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row8_col3 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row8_col4 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row9_col0 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row9_col1 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row9_col2 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row9_col3 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row9_col4 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row10_col0 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row10_col1 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row10_col2 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row10_col3 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row10_col4 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row11_col0 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row11_col1 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row11_col2 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row11_col3 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row11_col4 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row12_col0 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row12_col1 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row12_col2 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row12_col3 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row12_col4 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row13_col0 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row13_col1 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row13_col2 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row13_col3 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row13_col4 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row14_col0 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row14_col1 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row14_col2 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row14_col3 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row14_col4 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row15_col0 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row15_col1 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row15_col2 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row15_col3 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row15_col4 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row16_col0 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row16_col1 {
#             text-align:  left;
#         }    #T_2b5c574a_cf93_11ec_ab89_3448ed2f2355row16_col2 {
#             te
#
#   Translations of Shakespeare works in Dutch
# <style  type="text/css" >
#     #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355 th {
#           text-align: left;
#     }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row0_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row0_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row0_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row1_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row1_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row1_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row2_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row2_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row2_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row3_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row3_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row3_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row4_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row4_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row4_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row5_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row5_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row5_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row6_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row6_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row6_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row7_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row7_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row7_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row8_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row8_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row8_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row9_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row9_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row9_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row10_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row10_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row10_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row11_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row11_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row11_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row12_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row12_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row12_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row13_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row13_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row13_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row14_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row14_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row14_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row15_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row15_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row15_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row16_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row16_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row16_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row17_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row17_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row17_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row18_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row18_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row18_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row19_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row19_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row19_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row20_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row20_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row20_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row21_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row21_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row21_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row22_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row22_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row22_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row23_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row23_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row23_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row24_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row24_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row24_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row25_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row25_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row25_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row26_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row26_col1 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row26_col2 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row27_col0 {
#             text-align:  left;
#         }    #T_2fee4f9c_cf93_11ec_9182_3448ed2f2355row27_c

# %% [markdown]
# ### Commentary on section 1
#
# #### Commentary on topic 1
#
# We find in the top 20 numerous classical Roman and Greek authors such as Cicero, Plato, Aristotle, etc. Not surprising is the good score by Hugo Claus, Louis Paul Boon, Gerard Walschap, and Guido Gezelle. The university has indeed a Hugo Claus center, a Louis Paul Boon center, a Gerard Walschap Society and a Guido Gezelle center. We also find three French-speaking authors in the top 20: Jean de la Fontaine, Georges Simenon and Honoré de Balzac.
# Jean de la Fontaine's high ranking is due to Wim Gielen's collection of fable books that the library integrated in its holding a few years ago (https://anet.be/record/opaccoloiuantwerpen/co:ua:82).
#
# #### Commentary on topic 2
#
# At the top of the list we find Armel Guerne, translator of Grimm works in French, then Leendert Burgesdijk, the well-known translator of the entire work of the English playwright and poet William Shakespeare and after him we find Willy Corteaux, also a translator of Shakespeare (plays) but also and especially of the work of Euripides.
# Not surprisingly in the top 20 are the names of modern authors such as Hugo Claus and Gerrit Komrij (both also known as translators) and the presence of Joost van den Vondel who translated the works of Greek and Roman authors into Dutch.
#
#
# #### Commentary on topic 3
#
# The works of Claus are mostly translated as expected in French, German, and English, but in the library collection we also find many translations in less common languages as Turkish, Bulgarian, and Russian.
#
#
# #### Commentary on topic 4
#
# As established in the analysis of the translators, we find the names of Willy Courteaux, Leendert Burgersdijk and Gerrit Komrij in the list of shakespearean translations.

# %% [markdown]
# ## 2 : Language of the content
#
# - Topic 5: The aim is to map the most common languages in the collection of text editions. This query concerns the field 'content of the language' of the catalog records, not the field 'language of the title'. For example: the result set of a query for text editions in Dutch contains both the publications of Dutch and Flemish authors and the publications translated in Dutch.

# %%
# Query for Topic 5

query = '''
SELECT 
token.cloi,
language_lg as Language
FROM token 
JOIN 
author ON token.cloi = author.cloi
JOIN 
holding ON author.cloi = holding.cloi
JOIN 
title ON holding.cloi = title.cloi
JOIN 
subject ON subject.cloi = title.cloi
JOIN 
language ON subject.cloi = language.cloi
WHERE 
subject_ty LIKE 'PT'
AND subject_vw LIKE 'Tekstuitgave' 
AND holding.lib LIKE 'UA-CST'
AND title_ty LIKE 'h'

UNION

SELECT 
token.cloi,
language_lg as Language
FROM token 
JOIN 
author ON token.cloi = author.cloi
JOIN 
holding ON author.cloi = holding.cloi
JOIN 
title ON holding.cloi = title.cloi
JOIN 
subject ON subject.cloi = title.cloi
JOIN 
language ON subject.cloi = language.cloi
WHERE 
subject_ty LIKE 'PT'
AND subject_vw LIKE 'Theatertekst' 
AND holding.lib LIKE 'UA-CST'
AND title_ty LIKE 'h'

UNION

SELECT 
token.cloi,
language_lg as Language
FROM token 
JOIN 
author ON token.cloi = author.cloi
JOIN 
holding ON author.cloi = holding.cloi
JOIN 
title ON holding.cloi = title.cloi
JOIN 
subject ON subject.cloi = title.cloi
JOIN 
language ON subject.cloi = language.cloi
WHERE 
subject_ty LIKE 'PT'
AND subject_vw LIKE 'Poëzie' 
AND holding.lib LIKE 'UA-CST'
AND title_ty LIKE 'h'

UNION

SELECT 
token.cloi,
language_lg as Language
FROM token 
JOIN 
author ON token.cloi = author.cloi
JOIN 
holding ON author.cloi = holding.cloi
JOIN 
title ON holding.cloi = title.cloi
JOIN 
subject ON subject.cloi = title.cloi
JOIN 
language ON subject.cloi = language.cloi
WHERE 
subject_ty LIKE 'PT'
AND subject_vw LIKE 'Verhalend proza' 
AND holding.lib LIKE 'UA-CST'
AND title_ty LIKE 'h'

UNION

SELECT 
token.cloi,
language_lg as Language
FROM token 
JOIN 
author ON token.cloi = author.cloi
JOIN 
holding ON author.cloi = holding.cloi
JOIN 
title ON holding.cloi = title.cloi
JOIN 
subject ON subject.cloi = title.cloi
JOIN 
language ON subject.cloi = language.cloi
WHERE 
subject_ty LIKE 'PT'
AND subject_vw LIKE 'Beeldverhaal' 
AND holding.lib LIKE 'UA-CST'
AND title_ty LIKE 'h'

UNION

SELECT 
token.cloi,
language_lg as Language
FROM token 
JOIN 
author ON token.cloi = author.cloi
JOIN 
holding ON author.cloi = holding.cloi
JOIN 
title ON holding.cloi = title.cloi
JOIN 
subject ON subject.cloi = title.cloi
JOIN 
language ON subject.cloi = language.cloi
WHERE 
subject_ty LIKE 'PT'
AND subject_vw LIKE 'Bloemlezing' 
AND holding.lib LIKE 'UA-CST'
AND title_ty LIKE 'h'

'''
print_heading('Text editions: most common languages (top 20)')
styling_frame_count(execute_cursor(query, ['cloi', 'Language']), 'Language', 20)
# Out:
#
#  Text editions: most common languages (top 20)
# <style  type="text/css" >
#     #T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355 th {
#           text-align: left;
#     }    #T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row0_col0 {
#             text-align:  left;
#         }    #T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row1_col0 {
#             text-align:  left;
#         }    #T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row2_col0 {
#             text-align:  left;
#         }    #T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row3_col0 {
#             text-align:  left;
#         }    #T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row4_col0 {
#             text-align:  left;
#         }    #T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row5_col0 {
#             text-align:  left;
#         }    #T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row6_col0 {
#             text-align:  left;
#         }    #T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row7_col0 {
#             text-align:  left;
#         }    #T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row8_col0 {
#             text-align:  left;
#         }    #T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row9_col0 {
#             text-align:  left;
#         }    #T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row10_col0 {
#             text-align:  left;
#         }    #T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row11_col0 {
#             text-align:  left;
#         }    #T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row12_col0 {
#             text-align:  left;
#         }    #T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row13_col0 {
#             text-align:  left;
#         }    #T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row14_col0 {
#             text-align:  left;
#         }    #T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row15_col0 {
#             text-align:  left;
#         }    #T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row16_col0 {
#             text-align:  left;
#         }    #T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row17_col0 {
#             text-align:  left;
#         }    #T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row18_col0 {
#             text-align:  left;
#         }    #T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row19_col0 {
#             text-align:  left;
#         }</style><table id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of records</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355level0_row0" class="row_heading level0 row0" >dut</th>
#                         <td id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row0_col0" class="data row0 col0" >34044</td>
#             </tr>
#             <tr>
#                         <th id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355level0_row1" class="row_heading level0 row1" >fre</th>
#                         <td id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row1_col0" class="data row1 col0" >25147</td>
#             </tr>
#             <tr>
#                         <th id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355level0_row2" class="row_heading level0 row2" >eng</th>
#                         <td id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row2_col0" class="data row2 col0" >15433</td>
#             </tr>
#             <tr>
#                         <th id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355level0_row3" class="row_heading level0 row3" >ger</th>
#                         <td id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row3_col0" class="data row3 col0" >13320</td>
#             </tr>
#             <tr>
#                         <th id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355level0_row4" class="row_heading level0 row4" >spa</th>
#                         <td id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row4_col0" class="data row4 col0" >9252</td>
#             </tr>
#             <tr>
#                         <th id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355level0_row5" class="row_heading level0 row5" >lat</th>
#                         <td id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row5_col0" class="data row5 col0" >3494</td>
#             </tr>
#             <tr>
#                         <th id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355level0_row6" class="row_heading level0 row6" >ita</th>
#                         <td id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row6_col0" class="data row6 col0" >2139</td>
#             </tr>
#             <tr>
#                         <th id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355level0_row7" class="row_heading level0 row7" >por</th>
#                         <td id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row7_col0" class="data row7 col0" >805</td>
#             </tr>
#             <tr>
#                         <th id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355level0_row8" class="row_heading level0 row8" >rum</th>
#                         <td id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row8_col0" class="data row8 col0" >526</td>
#             </tr>
#             <tr>
#                         <th id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355level0_row9" class="row_heading level0 row9" >grc</th>
#                         <td id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row9_col0" class="data row9 col0" >386</td>
#             </tr>
#             <tr>
#                         <th id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355level0_row10" class="row_heading level0 row10" >afr</th>
#                         <td id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row10_col0" class="data row10 col0" >354</td>
#             </tr>
#             <tr>
#                         <th id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355level0_row11" class="row_heading level0 row11" >rus</th>
#                         <td id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row11_col0" class="data row11 col0" >273</td>
#             </tr>
#             <tr>
#                         <th id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355level0_row12" class="row_heading level0 row12" >swe</th>
#                         <td id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row12_col0" class="data row12 col0" >205</td>
#             </tr>
#             <tr>
#                         <th id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355level0_row13" class="row_heading level0 row13" >oci</th>
#                         <td id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row13_col0" class="data row13 col0" >192</td>
#             </tr>
#             <tr>
#                         <th id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355level0_row14" class="row_heading level0 row14" >yid</th>
#                         <td id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row14_col0" class="data row14 col0" >153</td>
#             </tr>
#             <tr>
#                         <th id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355level0_row15" class="row_heading level0 row15" >dan</th>
#                         <td id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row15_col0" class="data row15 col0" >149</td>
#             </tr>
#             <tr>
#                         <th id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355level0_row16" class="row_heading level0 row16" >gre</th>
#                         <td id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row16_col0" class="data row16 col0" >94</td>
#             </tr>
#             <tr>
#                         <th id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355level0_row17" class="row_heading level0 row17" >nor</th>
#                         <td id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row17_col0" class="data row17 col0" >79</td>
#             </tr>
#             <tr>
#                         <th id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355level0_row18" class="row_heading level0 row18" >nai</th>
#                         <td id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row18_col0" class="data row18 col0" >58</td>
#             </tr>
#             <tr>
#                         <th id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355level0_row19" class="row_heading level0 row19" >chi</th>
#                         <td id="T_a7d232cc_cf91_11ec_9ba7_3448ed2f2355row19_col0" class="data row19 col0" >54</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Commentary on section 2
#
# The library's collection is mainly focused on Dutch and French. English and German score significantly less but more than the remaining European and not European languages.

# %% [markdown]
# ## 3 : Autobiographies, correspondance, and diaries
#
# - Topic 6: Who are the authors with the most egodocuments in the library catalog?
# - Topic 7: Sample of 20 titles

# %%
# Query for Topic 6 and 7

query = '''
SELECT DISTINCT
 token.cloi,
 title_ti as Title,
 author_fn || ', ' || author_vn as Author
FROM token
JOIN holding 
ON token.cloi = holding.cloi
JOIN subject 
ON holding.cloi = subject.cloi
JOIN author 
ON author.cloi = subject.cloi
JOIN title 
ON author.cloi = title.cloi
JOIN subject2
ON title.cloi = subject2.cloi  
WHERE 
 author_fu like 'aut'
AND subject.subject_ac like 'a::920%'
AND Author == subject.subject_vw
AND  title_ty like 'h'
AND subject2.subject_ac like 'a::pt.4%'
'''
print_heading('Authors with the most egodocuments in the library catalog (top 20)')
styling_frame_count(execute_cursor(query, ['cloi','Title','Author']), 'Author', 20)

print_heading('Sample of 20 titles')
styling_frame(execute_cursor(query, ['cloi','Title','Author']), 20)
# Out:
#
#  Authors with the most egodocuments in the library catalog (top 20)
# <style  type="text/css" >
#     #T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355 th {
#           text-align: left;
#     }    #T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row0_col0 {
#             text-align:  left;
#         }    #T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row1_col0 {
#             text-align:  left;
#         }    #T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row2_col0 {
#             text-align:  left;
#         }    #T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row3_col0 {
#             text-align:  left;
#         }    #T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row4_col0 {
#             text-align:  left;
#         }    #T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row5_col0 {
#             text-align:  left;
#         }    #T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row6_col0 {
#             text-align:  left;
#         }    #T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row7_col0 {
#             text-align:  left;
#         }    #T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row8_col0 {
#             text-align:  left;
#         }    #T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row9_col0 {
#             text-align:  left;
#         }    #T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row10_col0 {
#             text-align:  left;
#         }    #T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row11_col0 {
#             text-align:  left;
#         }    #T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row12_col0 {
#             text-align:  left;
#         }    #T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row13_col0 {
#             text-align:  left;
#         }    #T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row14_col0 {
#             text-align:  left;
#         }    #T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row15_col0 {
#             text-align:  left;
#         }    #T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row16_col0 {
#             text-align:  left;
#         }    #T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row17_col0 {
#             text-align:  left;
#         }    #T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row18_col0 {
#             text-align:  left;
#         }    #T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row19_col0 {
#             text-align:  left;
#         }</style><table id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of records</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355level0_row0" class="row_heading level0 row0" >Gide, André</th>
#                         <td id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row0_col0" class="data row0 col0" >41</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355level0_row1" class="row_heading level0 row1" >Kafka, Franz</th>
#                         <td id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row1_col0" class="data row1 col0" >38</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355level0_row2" class="row_heading level0 row2" >Yourcenar, Marguerite</th>
#                         <td id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row2_col0" class="data row2 col0" >30</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355level0_row3" class="row_heading level0 row3" >Kierkegaard, Søren</th>
#                         <td id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row3_col0" class="data row3 col0" >27</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355level0_row4" class="row_heading level0 row4" >Goethe, von, Johann Wolfgang</th>
#                         <td id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row4_col0" class="data row4 col0" >23</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355level0_row5" class="row_heading level0 row5" >Frank, Anne</th>
#                         <td id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row5_col0" class="data row5 col0" >21</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355level0_row6" class="row_heading level0 row6" >Zweig, Stefan</th>
#                         <td id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row6_col0" class="data row6 col0" >19</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355level0_row7" class="row_heading level0 row7" >Joyce, James</th>
#                         <td id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row7_col0" class="data row7 col0" >19</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355level0_row8" class="row_heading level0 row8" >Canetti, Elias</th>
#                         <td id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row8_col0" class="data row8 col0" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355level0_row9" class="row_heading level0 row9" >Hofmannsthal, von, Hugo</th>
#                         <td id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row9_col0" class="data row9 col0" >17</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355level0_row10" class="row_heading level0 row10" >Boon, Louis Paul</th>
#                         <td id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row10_col0" class="data row10 col0" >14</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355level0_row11" class="row_heading level0 row11" >Rilke, Rainer Maria</th>
#                         <td id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row11_col0" class="data row11 col0" >14</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355level0_row12" class="row_heading level0 row12" >Mann, Thomas</th>
#                         <td id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row12_col0" class="data row12 col0" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355level0_row13" class="row_heading level0 row13" >Proust, Marcel</th>
#                         <td id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row13_col0" class="data row13 col0" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355level0_row14" class="row_heading level0 row14" >Freud, Sigmund</th>
#                         <td id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row14_col0" class="data row14 col0" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355level0_row15" class="row_heading level0 row15" >Rousseau, Jean-Jacques</th>
#                         <td id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row15_col0" class="data row15 col0" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355level0_row16" class="row_heading level0 row16" >Adorno, Theodor W.</th>
#                         <td id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row16_col0" class="data row16 col0" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355level0_row17" class="row_heading level0 row17" >Schnitzler, Arthur</th>
#                         <td id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row17_col0" class="data row17 col0" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355level0_row18" class="row_heading level0 row18" >Rimbaud, Arthur</th>
#                         <td id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row18_col0" class="data row18 col0" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355level0_row19" class="row_heading level0 row19" >Gezelle, Guido</th>
#                         <td id="T_b1a0683a_cf91_11ec_bc0e_3448ed2f2355row19_col0" class="data row19 col0" >12</td>
#             </tr>
#     </t
#
#  Sample of 20 titles
# <style  type="text/css" >
#     #T_b5258d1e_cf91_11ec_a727_3448ed2f2355 th {
#           text-align: left;
#     }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row0_col0 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row0_col1 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row0_col2 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row1_col0 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row1_col1 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row1_col2 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row2_col0 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row2_col1 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row2_col2 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row3_col0 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row3_col1 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row3_col2 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row4_col0 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row4_col1 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row4_col2 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row5_col0 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row5_col1 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row5_col2 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row6_col0 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row6_col1 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row6_col2 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row7_col0 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row7_col1 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row7_col2 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row8_col0 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row8_col1 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row8_col2 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row9_col0 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row9_col1 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row9_col2 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row10_col0 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row10_col1 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row10_col2 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row11_col0 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row11_col1 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row11_col2 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row12_col0 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row12_col1 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row12_col2 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row13_col0 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row13_col1 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row13_col2 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row14_col0 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row14_col1 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row14_col2 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row15_col0 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row15_col1 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row15_col2 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row16_col0 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row16_col1 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row16_col2 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row17_col0 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row17_col1 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row17_col2 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row18_col0 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row18_col1 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row18_col2 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row19_col0 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row19_col1 {
#             text-align:  left;
#         }    #T_b5258d1e_cf91_11ec_a727_3448ed2f2355row19_col2 {
#             text-align:  left;
#         }</style><table id="T_b5258d1e_cf91_11ec_a727_3448ed2f2355" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >cloi</th>        <th class="col_heading level0 col1" >Title</th>        <th class="col_heading level0 col2" >Author</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b5258d1e_cf91_11ec_a727_3448ed2f2355level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b5258d1e_cf91_11ec_a727_3448ed2f2355row0_col0" class="data row0 col0" >c:lvd:266897</td>
#                         <td id="T_b5258d1e_cf91_11ec_a727_3448ed2f2355row0_col1" class="data row0 col1" >Écrits de prison, précédés de: La vie de sir Thomas More</td>
#                         <td id="T_b5258d1e_cf91_11ec_a727_3448ed2f2355row0_col2" class="data row0 col2" >More, Thomas</td>
#             </tr>
#             <tr>
#                         <th id="T_b5258d1e_cf91_11ec_a727_3448ed2f2355level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b5258d1e_cf91_11ec_a727_3448ed2f2355row1_col0" class="data row1 col0" >c:lvd:3190389</td>
#                         <td id="T_b5258d1e_cf91_11ec_a727_3448ed2f2355row1_col1" class="data row1 col1" >Jetzt: Max Frisch</td>
#                         <td id="T_b5258d1e_cf91_11ec_a727_3448ed2f2355row1_col2" class="data row1 col2" >Frisch, Max</td>
#             </tr>
#             <tr>
#                         <th id="T_b5258d1e_cf91_11ec_a727_3448ed2f2355level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b5258d1e_cf91_11ec_a727_3448ed2f2355row2_col0" class="data row2 col0" >c:lvd:7098071</td>
#                         <td id="T_b5258d1e_cf91_11ec_a727_3448ed2f2355row2_col1" class="data row2 col1" >The basic writings of Bertrand Russell</td>
#                         <td id="T_b5258d1e_cf91_11ec_a727_3448ed2f2355row2_col2" class="data row2 col2" >Russell, Bertrand</td>
#             </tr>
#             <tr>
#                         <th id="T_b5258d1e_cf91_11ec_a727_3448ed2f2355level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b5258d1e_cf91_11ec

# %% [markdown]
# ### Commentary on section 3
#
# #### Commentary on topic 6
#
# The text editions of correspondence represent the largest part of the egodocuments. As a result, all authors whose correspondence has been published score very well in the ranking. Unfortunately, it is not possible to distinguish autobiographies from correspondence and diaries, because these editions are treated in the same way by the cataloguing rules.
#
# #### Commentary on topic 7
#
# On the basis of a sample it is difficult to draw conclusions. But the sample shows how varied the collection is.

# %% [markdown]
# ## 4 : Online available content
#
# - topic 8: The aim of this query is to determine which providers supply the largest online content in the library catalog. With online content we mean full text access to the text editions. Abstracts or summaries are thus obviously not considered as full text.

# %%
# Query for Topic 8

query = '''
SELECT DISTINCT
token.cloi,
title_ti as Title,
subject_vw as Subject,
fulltext_access as Access,
fulltext_loc as Provider,
fulltext_zurl as URL
FROM token
JOIN 
fulltext ON token.cloi = fulltext.cloi
JOIN 
title ON fulltext.cloi = title.cloi
JOIN 
holding ON title.cloi = holding.cloi
JOIN 
subject ON subject.cloi = holding.cloi
JOIN 
impressum ON subject.cloi = impressum.cloi
WHERE
fulltext_ty LIKE 'full'
AND subject_ty LIKE 'PT' 
AND Subject LIKE 'Theatertekst'
AND title_ty LIKE 'h'
AND (Access LIKE 'ua' OR Access LIKE 'anet' )
group by URL

UNION

SELECT DISTINCT
token.cloi,
title_ti as Title,
subject_vw as Subject,
fulltext_access as Access,
fulltext_loc as Provider,
fulltext_zurl as URL
FROM token
JOIN 
fulltext ON token.cloi = fulltext.cloi
JOIN 
title ON fulltext.cloi = title.cloi
JOIN 
holding ON title.cloi = holding.cloi
JOIN 
subject ON subject.cloi = holding.cloi
JOIN 
impressum ON subject.cloi = impressum.cloi
WHERE
fulltext_ty LIKE 'full'
AND subject_ty LIKE 'PT' 
AND Subject LIKE 'Tekstuitgave'
AND title_ty LIKE 'h'
AND (Access LIKE 'ua' OR Access LIKE 'anet' )
group by URL

UNION

SELECT DISTINCT
token.cloi,
title_ti as Title,
subject_vw as Subject,
fulltext_access as Access,
fulltext_loc as Provider,
fulltext_zurl as URL
FROM token
JOIN 
fulltext ON token.cloi = fulltext.cloi
JOIN 
title ON fulltext.cloi = title.cloi
JOIN 
holding ON title.cloi = holding.cloi
JOIN 
subject ON subject.cloi = holding.cloi
JOIN 
impressum ON subject.cloi = impressum.cloi
WHERE
fulltext_ty LIKE 'full'
AND subject_ty LIKE 'PT' 
AND Subject  LIKE 'Poëzie'
AND title_ty LIKE 'h'
AND (Access LIKE 'ua' OR Access LIKE 'anet' )
group by URL

UNION

SELECT DISTINCT
token.cloi,
title_ti as Title,
subject_vw as Subject,
fulltext_access as Access,
fulltext_loc as Provider,
fulltext_zurl as URL
FROM token
JOIN 
fulltext ON token.cloi = fulltext.cloi
JOIN 
title ON fulltext.cloi = title.cloi
JOIN 
holding ON title.cloi = holding.cloi
JOIN 
subject ON subject.cloi = holding.cloi
JOIN 
impressum ON subject.cloi = impressum.cloi
WHERE
fulltext_ty LIKE 'full'
AND subject_ty LIKE 'PT' 
AND Subject  LIKE 'Verhalend proza'
AND title_ty LIKE 'h'
AND (Access LIKE 'ua' OR Access LIKE 'anet' )
group by URL

UNION

SELECT DISTINCT
token.cloi,
title_ti as Title,
subject_vw as Subject,
fulltext_access as Access,
fulltext_loc as Provider,
fulltext_zurl as URL
FROM token
JOIN 
fulltext ON token.cloi = fulltext.cloi
JOIN 
title ON fulltext.cloi = title.cloi
JOIN 
holding ON title.cloi = holding.cloi
JOIN 
subject ON subject.cloi = holding.cloi
JOIN 
impressum ON subject.cloi = impressum.cloi
WHERE
fulltext_ty LIKE 'full'
AND subject_ty LIKE 'PT' 
AND Subject  LIKE 'Beeldverhaal'
AND title_ty LIKE 'h'
AND (Access LIKE 'ua' OR Access LIKE 'anet' )
group by URL

UNION

SELECT DISTINCT
token.cloi,
title_ti as Title,
subject_vw as Subject,
fulltext_access as Access,
fulltext_loc as Provider,
fulltext_zurl as URL
FROM token
JOIN 
fulltext ON token.cloi = fulltext.cloi
JOIN 
title ON fulltext.cloi = title.cloi
JOIN 
holding ON title.cloi = holding.cloi
JOIN 
subject ON subject.cloi = holding.cloi
JOIN 
impressum ON subject.cloi = impressum.cloi
WHERE
fulltext_ty LIKE 'full'
AND subject_ty LIKE 'PT' 
AND Subject  LIKE 'Bloemlezing'
AND title_ty LIKE 'h'
AND (Access LIKE 'ua' OR Access LIKE 'anet' )
group by URL

'''         
description = ['Google books', 'Google books from Hendrik Conscience heritage library', 'Digital library for Dutch literature', 'Google books from Plantin-Moretus Museum', 'Delpher']
print_heading('The online text editions: the biggest providers (top 5)')
styling_frame_count(execute_cursor(query, ['cloi', 'title_ti','subject_vw', 'fulltext_access', 'fulltext_loc', 'fulltext_zurl']), 'fulltext_loc', 5)
print("\n \n \033[1m\033[31m" + f'Legenda \n \n google_book = \N{TAB} \N{TAB} Google books \n google_book_ehc = \N{TAB} Google books from Hendrik Conscience heritage library \n dbnl-tekst = \N{TAB} \N{TAB} Digital library for Dutch literature \n google_book_mpm = \N{TAB} Google books from Plantin-Moretus Museum \n delpher = \N{TAB} \N{TAB} Delpher books    \033[0m ')
# Out:
#
#  The online text editions: the biggest providers (top 5)
# <style  type="text/css" >
#     #T_1496b10a_cfa0_11ec_aa23_3448ed2f2355 th {
#           text-align: left;
#     }    #T_1496b10a_cfa0_11ec_aa23_3448ed2f2355row0_col0 {
#             text-align:  left;
#         }    #T_1496b10a_cfa0_11ec_aa23_3448ed2f2355row1_col0 {
#             text-align:  left;
#         }    #T_1496b10a_cfa0_11ec_aa23_3448ed2f2355row2_col0 {
#             text-align:  left;
#         }    #T_1496b10a_cfa0_11ec_aa23_3448ed2f2355row3_col0 {
#             text-align:  left;
#         }    #T_1496b10a_cfa0_11ec_aa23_3448ed2f2355row4_col0 {
#             text-align:  left;
#         }</style><table id="T_1496b10a_cfa0_11ec_aa23_3448ed2f2355" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of records</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1496b10a_cfa0_11ec_aa23_3448ed2f2355level0_row0" class="row_heading level0 row0" >google_book_ehc</th>
#                         <td id="T_1496b10a_cfa0_11ec_aa23_3448ed2f2355row0_col0" class="data row0 col0" >438</td>
#             </tr>
#             <tr>
#                         <th id="T_1496b10a_cfa0_11ec_aa23_3448ed2f2355level0_row1" class="row_heading level0 row1" >google_book</th>
#                         <td id="T_1496b10a_cfa0_11ec_aa23_3448ed2f2355row1_col0" class="data row1 col0" >375</td>
#             </tr>
#             <tr>
#                         <th id="T_1496b10a_cfa0_11ec_aa23_3448ed2f2355level0_row2" class="row_heading level0 row2" >dbnl-tekst</th>
#                         <td id="T_1496b10a_cfa0_11ec_aa23_3448ed2f2355row2_col0" class="data row2 col0" >278</td>
#             </tr>
#             <tr>
#                         <th id="T_1496b10a_cfa0_11ec_aa23_3448ed2f2355level0_row3" class="row_heading level0 row3" >google_book_mpm</th>
#                         <td id="T_1496b10a_cfa0_11ec_aa23_3448ed2f2355row3_col0" class="data row3 col0" >74</td>
#             </tr>
#             <tr>
#                         <th id="T_1496b10a_cfa0_11ec_aa23_3448ed2f2355level0_row4" class="row_heading level0 row4" >delpher</th>
#                         <td id="T_1496b10a_cfa0_11ec_aa23_3448ed2f2355row4_col0" class="data row4 col0" >42</td>
#             </tr>
#     </tbody></table>
#
#  Legenda
#
#  google_book = 	 	 Google books
#  google_book_ehc = 	 Google books from Hendrik Conscience heritage library
#  dbnl-tekst = 	 	 Digital library for Dutch literature
#  google_book_mpm = 	 Google books from Plantin-Moretus Museum
#  delpher = 	 	 Delpher books

# %% [markdown]
# ### Commentary on section 4
#
# The digitization via Google projects score particularly well, but the Digital library for Dutch literature plays an important role for text editions in Dutch (works of Flemish and Dutch authors).
# This means that especially books that are copyright free are available. Recent content in the form of e-books is hardly present in the collection.

# %% [markdown]
# ## 5 : German literature
#
# - Topic 9: Which German authors are the most common in the collection of text editions?
# - Topic 10: The predominant language of these publications is obviously German, but in which other languages are these works published?

# %%
# Query for Topic 9 and 10

query = '''
SELECT DISTINCT
token.cloi,
title_ti AS Title,
author_fn || ', ' || author_vn AS Author,
language_lg AS Language
FROM token
JOIN 
holding ON token.cloi = holding.cloi
JOIN 
title ON holding.cloi = title.cloi
JOIN 
subject ON subject.cloi = title.cloi
JOIN 
relation ON subject.cloi = relation.cloi
JOIN 
author on author.cloi = relation.cloi
JOIN 
subject2 ON author.cloi = subject2.cloi
JOIN 
language ON language.cloi = subject2.cloi
WHERE 
holding.lib LIKE 'UA-CST'
AND subject.subject_ac LIKE 'a::pt.41:1'
AND title_ty LIKE 'h'
AND subject2.subject_vw LIKE 'Duitse Letterkunde'
GROUP BY token.cloi

UNION

SELECT DISTINCT
token.cloi,
title_ti AS Title,
author_fn || ', ' || author_vn AS Author,
language_lg AS Language
FROM token
JOIN 
holding ON token.cloi = holding.cloi
JOIN 
title ON holding.cloi = title.cloi
JOIN 
subject ON subject.cloi = title.cloi
JOIN 
relation ON subject.cloi = relation.cloi
JOIN 
author on author.cloi = relation.cloi
JOIN 
subject2 ON author.cloi = subject2.cloi
JOIN 
language ON language.cloi = subject2.cloi
WHERE 
holding.lib LIKE 'UA-CST'
AND subject.subject_ac LIKE 'a::pt.42:1'
AND title_ty LIKE 'h'
AND subject2.subject_vw LIKE 'Duitse Letterkunde'
GROUP BY token.cloi

UNION

SELECT DISTINCT
token.cloi,
title_ti AS Title,
author_fn || ', ' || author_vn AS Author,
language_lg AS Language
FROM token
JOIN 
holding ON token.cloi = holding.cloi
JOIN 
title ON holding.cloi = title.cloi
JOIN 
subject ON subject.cloi = title.cloi
JOIN 
relation ON subject.cloi = relation.cloi
JOIN 
author on author.cloi = relation.cloi
JOIN 
subject2 ON author.cloi = subject2.cloi
JOIN 
language ON language.cloi = subject2.cloi
WHERE 
holding.lib LIKE 'UA-CST'
AND subject.subject_ac LIKE 'a::pt.43:1'
AND title_ty LIKE 'h'
AND subject2.subject_vw LIKE 'Duitse Letterkunde'
GROUP BY token.cloi

UNION

SELECT DISTINCT
token.cloi,
title_ti AS Title,
author_fn || ', ' || author_vn AS Author,
language_lg AS Language
FROM token
JOIN 
holding ON token.cloi = holding.cloi
JOIN 
title ON holding.cloi = title.cloi
JOIN 
subject ON subject.cloi = title.cloi
JOIN 
relation ON subject.cloi = relation.cloi
JOIN 
author on author.cloi = relation.cloi
JOIN 
subject2 ON author.cloi = subject2.cloi
JOIN 
language ON language.cloi = subject2.cloi
WHERE 
holding.lib LIKE 'UA-CST'
AND subject.subject_ac LIKE 'a::pt.46:1'
AND title_ty LIKE 'h'
AND subject2.subject_vw LIKE 'Duitse Letterkunde'
GROUP BY token.cloi

UNION

SELECT DISTINCT
token.cloi,
title_ti AS Title,
author_fn || ', ' || author_vn AS Author,
language_lg AS Language
FROM token
JOIN 
holding ON token.cloi = holding.cloi
JOIN 
title ON holding.cloi = title.cloi
JOIN 
subject ON subject.cloi = title.cloi
JOIN 
relation ON subject.cloi = relation.cloi
JOIN 
author on author.cloi = relation.cloi
JOIN 
subject2 ON author.cloi = subject2.cloi
JOIN 
language ON language.cloi = subject2.cloi
WHERE 
holding.lib LIKE 'UA-CST'
AND subject.subject_ac LIKE 'a::pt.47:1'
AND title_ty LIKE 'h'
AND subject2.subject_vw LIKE 'Duitse Letterkunde'
GROUP BY token.cloi

UNION

SELECT DISTINCT
token.cloi,
title_ti AS Title,
author_fn || ', ' || author_vn AS Author,
language_lg AS Language
FROM token
JOIN 
holding ON token.cloi = holding.cloi
JOIN 
title ON holding.cloi = title.cloi
JOIN 
subject ON subject.cloi = title.cloi
JOIN 
relation ON subject.cloi = relation.cloi
JOIN 
author on author.cloi = relation.cloi
JOIN 
subject2 ON author.cloi = subject2.cloi
JOIN 
language ON language.cloi = subject2.cloi
WHERE 
holding.lib LIKE 'UA-CST'
AND subject.subject_ac LIKE 'a::pt.17:1'
AND title_ty LIKE 'h'
AND subject2.subject_vw LIKE 'Duitse Letterkunde'
GROUP BY token.cloi

'''
print_heading('German authors of text editions (top 20)')
styling_frame_count(execute_cursor(query, ['cloi', 'title_ti','author_name', 'language_lg']), 'author_name', 20)
print_heading('Languages of German text editions')
styling_frame_count(execute_cursor(query, ['cloi', 'title_ti','author_name', 'language_lg']), 'language_lg', 5)
# Out:
#
#  German authors of text editions (top 20)
# <style  type="text/css" >
#     #T_e754df92_cf91_11ec_948e_3448ed2f2355 th {
#           text-align: left;
#     }    #T_e754df92_cf91_11ec_948e_3448ed2f2355row0_col0 {
#             text-align:  left;
#         }    #T_e754df92_cf91_11ec_948e_3448ed2f2355row1_col0 {
#             text-align:  left;
#         }    #T_e754df92_cf91_11ec_948e_3448ed2f2355row2_col0 {
#             text-align:  left;
#         }    #T_e754df92_cf91_11ec_948e_3448ed2f2355row3_col0 {
#             text-align:  left;
#         }    #T_e754df92_cf91_11ec_948e_3448ed2f2355row4_col0 {
#             text-align:  left;
#         }    #T_e754df92_cf91_11ec_948e_3448ed2f2355row5_col0 {
#             text-align:  left;
#         }    #T_e754df92_cf91_11ec_948e_3448ed2f2355row6_col0 {
#             text-align:  left;
#         }    #T_e754df92_cf91_11ec_948e_3448ed2f2355row7_col0 {
#             text-align:  left;
#         }    #T_e754df92_cf91_11ec_948e_3448ed2f2355row8_col0 {
#             text-align:  left;
#         }    #T_e754df92_cf91_11ec_948e_3448ed2f2355row9_col0 {
#             text-align:  left;
#         }    #T_e754df92_cf91_11ec_948e_3448ed2f2355row10_col0 {
#             text-align:  left;
#         }    #T_e754df92_cf91_11ec_948e_3448ed2f2355row11_col0 {
#             text-align:  left;
#         }    #T_e754df92_cf91_11ec_948e_3448ed2f2355row12_col0 {
#             text-align:  left;
#         }    #T_e754df92_cf91_11ec_948e_3448ed2f2355row13_col0 {
#             text-align:  left;
#         }    #T_e754df92_cf91_11ec_948e_3448ed2f2355row14_col0 {
#             text-align:  left;
#         }    #T_e754df92_cf91_11ec_948e_3448ed2f2355row15_col0 {
#             text-align:  left;
#         }    #T_e754df92_cf91_11ec_948e_3448ed2f2355row16_col0 {
#             text-align:  left;
#         }    #T_e754df92_cf91_11ec_948e_3448ed2f2355row17_col0 {
#             text-align:  left;
#         }    #T_e754df92_cf91_11ec_948e_3448ed2f2355row18_col0 {
#             text-align:  left;
#         }    #T_e754df92_cf91_11ec_948e_3448ed2f2355row19_col0 {
#             text-align:  left;
#         }</style><table id="T_e754df92_cf91_11ec_948e_3448ed2f2355" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of records</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e754df92_cf91_11ec_948e_3448ed2f2355level0_row0" class="row_heading level0 row0" >Grimm, </th>
#                         <td id="T_e754df92_cf91_11ec_948e_3448ed2f2355row0_col0" class="data row0 col0" >311</td>
#             </tr>
#             <tr>
#                         <th id="T_e754df92_cf91_11ec_948e_3448ed2f2355level0_row1" class="row_heading level0 row1" >Goethe, von, Johann Wolfgang</th>
#                         <td id="T_e754df92_cf91_11ec_948e_3448ed2f2355row1_col0" class="data row1 col0" >120</td>
#             </tr>
#             <tr>
#                         <th id="T_e754df92_cf91_11ec_948e_3448ed2f2355level0_row2" class="row_heading level0 row2" >Brecht, Bertolt</th>
#                         <td id="T_e754df92_cf91_11ec_948e_3448ed2f2355row2_col0" class="data row2 col0" >105</td>
#             </tr>
#             <tr>
#                         <th id="T_e754df92_cf91_11ec_948e_3448ed2f2355level0_row3" class="row_heading level0 row3" >Kafka, Franz</th>
#                         <td id="T_e754df92_cf91_11ec_948e_3448ed2f2355row3_col0" class="data row3 col0" >98</td>
#             </tr>
#             <tr>
#                         <th id="T_e754df92_cf91_11ec_948e_3448ed2f2355level0_row4" class="row_heading level0 row4" >Böll, Heinrich</th>
#                         <td id="T_e754df92_cf91_11ec_948e_3448ed2f2355row4_col0" class="data row4 col0" >83</td>
#             </tr>
#             <tr>
#                         <th id="T_e754df92_cf91_11ec_948e_3448ed2f2355level0_row5" class="row_heading level0 row5" >Schnitzler, Arthur</th>
#                         <td id="T_e754df92_cf91_11ec_948e_3448ed2f2355row5_col0" class="data row5 col0" >80</td>
#             </tr>
#             <tr>
#                         <th id="T_e754df92_cf91_11ec_948e_3448ed2f2355level0_row6" class="row_heading level0 row6" >Bernhard, Thomas</th>
#                         <td id="T_e754df92_cf91_11ec_948e_3448ed2f2355row6_col0" class="data row6 col0" >79</td>
#             </tr>
#             <tr>
#                         <th id="T_e754df92_cf91_11ec_948e_3448ed2f2355level0_row7" class="row_heading level0 row7" >Döblin, Alfred</th>
#                         <td id="T_e754df92_cf91_11ec_948e_3448ed2f2355row7_col0" class="data row7 col0" >71</td>
#             </tr>
#             <tr>
#                         <th id="T_e754df92_cf91_11ec_948e_3448ed2f2355level0_row8" class="row_heading level0 row8" >Mann, Thomas</th>
#                         <td id="T_e754df92_cf91_11ec_948e_3448ed2f2355row8_col0" class="data row8 col0" >71</td>
#             </tr>
#             <tr>
#                         <th id="T_e754df92_cf91_11ec_948e_3448ed2f2355level0_row9" class="row_heading level0 row9" >Handke, Peter</th>
#                         <td id="T_e754df92_cf91_11ec_948e_3448ed2f2355row9_col0" class="data row9 col0" >63</td>
#             </tr>
#             <tr>
#                         <th id="T_e754df92_cf91_11ec_948e_3448ed2f2355level0_row10" class="row_heading level0 row10" >Hesse, Hermann</th>
#                         <td id="T_e754df92_cf91_11ec_948e_3448ed2f2355row10_col0" class="data row10 col0" >55</td>
#             </tr>
#             <tr>
#                         <th id="T_e754df92_cf91_11ec_948e_3448ed2f2355level0_row11" class="row_heading level0 row11" >Nestroy, Johann</th>
#                         <td id="T_e754df92_cf91_11ec_948e_3448ed2f2355row11_col0" class="data row11 col0" >55</td>
#             </tr>
#             <tr>
#                         <th id="T_e754df92_cf91_11ec_948e_3448ed2f2355level0_row12" class="row_heading level0 row12" >Nietzsche, Friedrich</th>
#                         <td id="T_e754df92_cf91_11ec_948e_3448ed2f2355row12_col0" class="data row12 col0" >54</td>
#             </tr>
#             <tr>
#                         <th id="T_e754df92_cf91_11ec_948e_3448ed2f2355level0_row13" class="row_heading level0 row13" >Seghers, Anna</th>
#                         <td id="T_e754df92_cf91_11ec_948e_3448ed2f2355row13_col0" class="data row13 col0" >52</td>
#             </tr>
#             <tr>
#                         <th id="T_e754df92_cf91_11ec_948e_3448ed2f2355level0_row14" class="row_heading level0 row14" >Grass, Günter</th>
#                         <td id="T_e754df92_cf91_11ec_948e_3448ed2f2355row14_col0" class="data row14 col0" >51</td>
#             </tr>
#             <tr>
#                         <th id="T_e754df92_cf91_11ec_948e_3448ed2f2355level0_row15" class="row_heading level0 row15" >Celan, Paul</th>
#                         <td id="T_e754df92_cf91_11ec_948e_3448ed2f2355row15_col0" class="data row15 col0" >50</td>
#             </tr>
#             <tr>
#                         <th id="T_e754df92_cf91_11ec_948e_3448ed2f2355level0_row16" class="row_heading level0 row16" >Lessing, Gotthold Ephraim</th>
#                         <td id="T_e754df92_cf91_11ec_948e_3448ed2f2355row16_col0" class="data row16 col0" >47</td>
#             </tr>
#             <tr>
#                         <th id="T_e754df92_cf91_11ec_948e_3448ed2f2355level0_row17" class="row_heading level0 row17" >Rilke, Rainer Maria</th>
#                         <td id="T_e754df92_cf91_11ec_948e_3448ed2f2355row17_col0" class="data row17 col0" >47</td>
#             </tr>
#             <tr>
#                         <th id="T_e754df92_cf91_11ec_948e_3448ed2f2355level0_row18" class="row_heading level0 row18" >Hofmannsthal, von, Hugo</th>
#                         <td id="T_e754df92_cf91_11ec_948e_3448ed2f2355row18_col0" class="data row18 col0" >45</td>
#             </tr>
#             <tr>
#                         <th id="T_e754df92_cf91_11ec_948e_3448ed2f2355level0_row19" class="row_heading level0 row19" >Schiller, von, Friedrich</th>
#                         <td id="T_e754df92_cf91_11ec_948e_3448ed2f2355row19_col0" class="data row19 col0" >43</td>
#             </tr>
#
#  Languages of German text editions
# <style  type="text/css" >
#     #T_fc4fda52_cf91_11ec_8d8b_3448ed2f2355 th {
#           text-align: left;
#     }    #T_fc4fda52_cf91_11ec_8d8b_3448ed2f2355row0_col0 {
#             text-align:  left;
#         }    #T_fc4fda52_cf91_11ec_8d8b_3448ed2f2355row1_col0 {
#             text-align:  left;
#         }    #T_fc4fda52_cf91_11ec_8d8b_3448ed2f2355row2_col0 {
#             text-align:  left;
#         }    #T_fc4fda52_cf91_11ec_8d8b_3448ed2f2355row3_col0 {
#             text-align:  left;
#         }    #T_fc4fda52_cf91_11ec_8d8b_3448ed2f2355row4_col0 {
#             text-align:  left;
#         }</style><table id="T_fc4fda52_cf91_11ec_8d8b_3448ed2f2355" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of records</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fc4fda52_cf91_11ec_8d8b_3448ed2f2355level0_row0" class="row_heading level0 row0" >ger</th>
#                         <td id="T_fc4fda52_cf91_11ec_8d8b_3448ed2f2355row0_col0" class="data row0 col0" >6432</td>
#             </tr>
#             <tr>
#                         <th id="T_fc4fda52_cf91_11ec_8d8b_3448ed2f2355level0_row1" class="row_heading level0 row1" >dut</th>
#                         <td id="T_fc4fda52_cf91_11ec_8d8b_3448ed2f2355row1_col0" class="data row1 col0" >715</td>
#             </tr>
#             <tr>
#                         <th id="T_fc4fda52_cf91_11ec_8d8b_3448ed2f2355level0_row2" class="row_heading level0 row2" >fre</th>
#                         <td id="T_fc4fda52_cf91_11ec_8d8b_3448ed2f2355row2_col0" class="data row2 col0" >526</td>
#             </tr>
#             <tr>
#                         <th id="T_fc4fda52_cf91_11ec_8d8b_3448ed2f2355level0_row3" class="row_heading level0 row3" >eng</th>
#                         <td id="T_fc4fda52_cf91_11ec_8d8b_3448ed2f2355row3_col0" class="data row3 col0" >87</td>
#             </tr>
#             <tr>
#                         <th id="T_fc4fda52_cf91_11ec_8d8b_3448ed2f2355level0_row4" class="row_heading level0 row4" >spa</th>
#                         <td id="T_fc4fda52_cf91_11ec_8d8b_3448ed2f2355row4_col0" class="data row4 col0" >17</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Commentary on section 5
#
# #### Commentary on topic 9
#
# If we consider the top 20, we can conclude that there is not a single 'contemporary' author, namely authors that have largely published the last ten or twenty years. This could point to the fact that in recent years no attention has been paid in the collection building to new novels or poems.
#
# As already mentioned in section 1, the high ranking of the Brothers Grimm is due to the fable books collected by Wim Gielen, and especially due to the collection of children's literature donated by Johannes Bronkhorst (https://anet.be/record/opaccoloiuantwerpen/co:ua:155).
#
# #### Commentary on topic 10
#
# There is a relatively large number of translations of German text editions into Dutch and French, as might be expected. On the contrary, English translations are less available.

# %% [markdown]
# ## 6 : Year of publication
#
# - Topic 11: The aim of this section is to look at the year of publication. This is important to determine how the collection is grown over the years. The year of publication says nothing about the relevance of the text editions, but it could be in any case an indicator of the purchase policy of the faculty.

# %%
# Query for Topic 11

query = '''
SELECT DISTINCT
    token.cloi,
    impressum_ju1sv as Year
FROM token 
JOIN 
author ON token.cloi = author.cloi
JOIN 
holding ON author.cloi = holding.cloi
JOIN 
title ON holding.cloi = title.cloi
JOIN 
subject ON subject.cloi = title.cloi
JOIN 
language ON subject.cloi = language.cloi
JOIN 
impressum ON impressum.cloi = language.cloi
WHERE 
subject_ty LIKE 'PT'
AND (subject_vw LIKE 'Theatertekst' OR subject_vw LIKE 'Tekstuitgave' OR subject_vw LIKE 'Poëzie' OR subject_vw LIKE 'Verhalend proza'
OR subject_vw LIKE 'Beeldverhaal' OR subject_vw LIKE 'Bloemlezing')
AND holding.lib LIKE 'UA-CST'
AND title_ty LIKE 'h'
GROUP BY token.cloi
'''
print_heading('Text editions: year of publication (top 30)')
styling_frame_count(execute_cursor(query, ['cloi', 'year']), 'year', 30)
# Out:
#
#  Text editions: year of publication (top 30)
# <style  type="text/css" >
#     #T_0702efec_cf92_11ec_9823_3448ed2f2355 th {
#           text-align: left;
#     }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row0_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row1_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row2_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row3_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row4_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row5_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row6_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row7_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row8_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row9_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row10_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row11_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row12_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row13_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row14_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row15_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row16_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row17_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row18_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row19_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row20_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row21_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row22_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row23_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row24_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row25_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row26_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row27_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row28_col0 {
#             text-align:  left;
#         }    #T_0702efec_cf92_11ec_9823_3448ed2f2355row29_col0 {
#             text-align:  left;
#         }</style><table id="T_0702efec_cf92_11ec_9823_3448ed2f2355" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of records</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0702efec_cf92_11ec_9823_3448ed2f2355level0_row0" class="row_heading level0 row0" ></th>
#                         <td id="T_0702efec_cf92_11ec_9823_3448ed2f2355row0_col0" class="data row0 col0" >3239</td>
#             </tr>
#             <tr>
#                         <th id="T_0702efec_cf92_11ec_9823_3448ed2f2355level0_row1" class="row_heading level0 row1" >1980</th>
#                         <td id="T_0702efec_cf92_11ec_9823_3448ed2f2355row1_col0" class="data row1 col0" >1790</td>
#             </tr>
#             <tr>
#                         <th id="T_0702efec_cf92_11ec_9823_3448ed2f2355level0_row2" class="row_heading level0 row2" >1977</th>
#                         <td id="T_0702efec_cf92_11ec_9823_3448ed2f2355row2_col0" class="data row2 col0" >1728</td>
#             </tr>
#             <tr>
#                         <th id="T_0702efec_cf92_11ec_9823_3448ed2f2355level0_row3" class="row_heading level0 row3" >1976</th>
#                         <td id="T_0702efec_cf92_11ec_9823_3448ed2f2355row3_col0" class="data row3 col0" >1727</td>
#             </tr>
#             <tr>
#                         <th id="T_0702efec_cf92_11ec_9823_3448ed2f2355level0_row4" class="row_heading level0 row4" >1975</th>
#                         <td id="T_0702efec_cf92_11ec_9823_3448ed2f2355row4_col0" class="data row4 col0" >1711</td>
#             </tr>
#             <tr>
#                         <th id="T_0702efec_cf92_11ec_9823_3448ed2f2355level0_row5" class="row_heading level0 row5" >1974</th>
#                         <td id="T_0702efec_cf92_11ec_9823_3448ed2f2355row5_col0" class="data row5 col0" >1698</td>
#             </tr>
#             <tr>
#                         <th id="T_0702efec_cf92_11ec_9823_3448ed2f2355level0_row6" class="row_heading level0 row6" >1995</th>
#                         <td id="T_0702efec_cf92_11ec_9823_3448ed2f2355row6_col0" class="data row6 col0" >1694</td>
#             </tr>
#             <tr>
#                         <th id="T_0702efec_cf92_11ec_9823_3448ed2f2355level0_row7" class="row_heading level0 row7" >1994</th>
#                         <td id="T_0702efec_cf92_11ec_9823_3448ed2f2355row7_col0" class="data row7 col0" >1694</td>
#             </tr>
#             <tr>
#                         <th id="T_0702efec_cf92_11ec_9823_3448ed2f2355level0_row8" class="row_heading level0 row8" >1972</th>
#                         <td id="T_0702efec_cf92_11ec_9823_3448ed2f2355row8_col0" class="data row8 col0" >1675</td>
#             </tr>
#             <tr>
#                         <th id="T_0702efec_cf92_11ec_9823_3448ed2f2355level0_row9" class="row_heading level0 row9" >1978</th>
#                         <td id="T_0702efec_cf92_11ec_9823_3448ed2f2355row9_col0" class="data row9 col0" >1670</td>
#             </tr>
#             <tr>
#                         <th id="T_0702efec_cf92_11ec_9823_3448ed2f2355level0_row10" class="row_heading level0 row10" >1973</th>
#                         <td id="T_0702efec_cf92_11ec_9823_3448ed2f2355row10_col0" class="data row10 col0" >1663</td>
#             </tr>
#             <tr>
#                         <th id="T_0702efec_cf92_11ec_9823_3448ed2f2355level0_row11" class="row_heading level0 row11" >1979</th>
#                         <td id="T_0702efec_cf92_11ec_9823_3448ed2f2355row11_col0" class="data row11 col0" >1655</td>
#             </tr>
#             <tr>
#                         <th id="T_0702efec_cf92_11ec_9823_3448ed2f2355level0_row12" class="row_heading level0 row12" >1989</th>
#                         <td id="T_0702efec_cf92_11ec_9823_3448ed2f2355row12_col0" class="data row12 col0" >1624</td>
#             </tr>
#             <tr>
#                         <th id="T_0702efec_cf92_11ec_9823_3448ed2f2355level0_row13" class="row_heading level0 row13" >1990</th>
#                         <td id="T_0702efec_cf92_11ec_9823_3448ed2f2355row13_col0" class="data row13 col0" >1623</td>
#             </tr>
#             <tr>
#                         <th id="T_0702efec_cf92_11ec_9823_3448ed2f2355level0_row14" class="row_heading level0 row14" >1992</th>
#                         <td id="T_0702efec_cf92_11ec_9823_3448ed2f2355row14_col0" class="data row14 col0" >1584</td>
#             </tr>
#             <tr>
#                         <th id="T_0702efec_cf92_11ec_9823_3448ed2f2355level0_row15" class="row_heading level0 row15" >1996</th>
#                         <td id="T_0702efec_cf92_11ec_9823_3448ed2f2355row15_col0" class="data row15 col0" >1579</td>
#             </tr>
#             <tr>
#                         <th id="T_0702efec_cf92_11ec_9823_3448ed2f2355level0_row16" class="row_heading level0 row16" >1981</th>
#                         <td id="T_0702efec_cf92_11ec_9823_3448ed2f2355row16_col0" class="data row16 col0" >1556</td>
#             </tr>
#             <tr>
#                         <th id="T_0702efec_cf92_11ec_9823_3448ed2f2355level0_ro

# %% [markdown]
# ### Commentary on section 6
#
# There is no year of publication of the period 2001-2021. This is once again a clear indication that little has been invested the last years in text editions (German literature).
